# %% [markdown]
# # ICP01 Jupyter Install
# ## Prathyusha Thummalapalli

# %% [markdown]
# ![WhatsApp%20Image%202023-02-10%20at%2010.24.29%20PM.jpeg](attachment:WhatsApp%20Image%202023-02-10%20at%2010.24.29%20PM.jpeg)
# This is Prathyusha Thummalapalli. I am currently pursuing MS in BAIS at University of South Florida and is a Graduate Assistant under Prof. Dennis Walpole for Computers in Business. Prior to this I worked as a Data Migration Consultant for 3 years.

# %%
print('Hello World')
# Out:
# Hello World
